# %% [markdown]
# # HW06

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.spatial as spa
import scipy.stats as stats
import math

# %% [markdown]
# ## Parameters

# %%
np.random.seed(421)

# cluster count
K = 5


# mean parameters
class_means = np.array([[+2.5, +2.5], 
                        [-2.5, +2.5], 
                        [-2.5, -2.5],
                        [+2.5, -2.5],
                        [+0.0, +0.0]])
# covariance parameters
class_covariances = np.array([[[+0.8, -0.6], 
                               [-0.6, +0.8]],
                              [[+0.8, +0.6], 
                               [+0.6, +0.8]],
                              [[+0.8, -0.6], 
                               [-0.6, +0.8]],
                              [[+0.8, +0.6], 
                               [+0.6, +0.8]],
                              [[+1.6, +0.0], 
                               [+0.0, +1.6]]])
# sample sizes
class_sizes = np.array([50, 50, 50, 50, 100])
N = 300

# %% [markdown]
# ## Data Generation

# %%
# generate random samples
points1 = np.random.multivariate_normal(class_means[0,:], class_covariances[0,:,:], class_sizes[0])
points2 = np.random.multivariate_normal(class_means[1,:], class_covariances[1,:,:], class_sizes[1])
points3 = np.random.multivariate_normal(class_means[2,:], class_covariances[2,:,:], class_sizes[2])
points4 = np.random.multivariate_normal(class_means[3,:], class_covariances[3,:,:], class_sizes[3])
points5 = np.random.multivariate_normal(class_means[4,:], class_covariances[4,:,:], class_sizes[4])
X = np.concatenate((points1, points2, points3, points4, points5))

plt.figure(figsize = (10, 10))
plt.scatter(points1[:,0], points1[:,1], color="black")
plt.scatter(points2[:,0], points2[:,1], color="black")
plt.scatter(points3[:,0], points3[:,1], color="black")
plt.scatter(points4[:,0], points4[:,1], color="black")
plt.scatter(points5[:,0], points5[:,1], color="black")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

"""
data_interval = np.linspace(-7, +7, 1401)
density1 = stats.norm.pdf(data_interval, loc = class_means[0], scale = class_covariances[0])
density2 = stats.norm.pdf(data_interval, loc = class_means[1], scale = class_covariances[1])
density3 = stats.norm.pdf(data_interval, loc = class_means[2], scale = class_covariances[2])
density4 = stats.norm.pdf(data_interval, loc = class_means[3], scale = class_covariances[3])
density5 = stats.norm.pdf(data_interval, loc = class_means[4], scale = class_covariances[4])
plt.plot(data_interval, density1, "r")
plt.plot(data_interval, density2, "r")
plt.plot(data_interval, density3, "r")
plt.plot(data_interval, density4, "r")
plt.plot(data_interval, density5, "r")

plt.plot(points1, np.repeat(-0.01, class_sizes[0]), "r.", markersize = 10)
plt.plot(points2, np.repeat(-0.01, class_sizes[1]), "r.", markersize = 10)
plt.plot(points3, np.repeat(-0.01, class_sizes[2]), "r.", markersize = 10)
plt.plot(points4, np.repeat(-0.01, class_sizes[3]), "r.", markersize = 10)
plt.plot(points5, np.repeat(-0.01, class_sizes[4]), "r.", markersize = 10)
"""
# Out:
# '\ndata_interval = np.linspace(-7, +7, 1401)\ndensity1 = stats.norm.pdf(data_interval, loc = class_means[0], scale = class_covariances[0])\ndensity2 = stats.norm.pdf(data_interval, loc = class_means[1], scale = class_covariances[1])\ndensity3 = stats.norm.pdf(data_interval, loc = class_means[2], scale = class_covariances[2])\ndensity4 = stats.norm.pdf(data_interval, loc = class_means[3], scale = class_covariances[3])\ndensity5 = stats.norm.pdf(data_interval, loc = class_means[4], scale = class_covariances[4])\nplt.plot(data_interval, density1, "r")\nplt.plot(data_interval, density2, "r")\nplt.plot(data_interval, density3, "r")\nplt.plot(data_interval, density4, "r")\nplt.plot(data_interval, density5, "r")\n\nplt.plot(points1, np.repeat(-0.01, class_sizes[0]), "r.", markersize = 10)\nplt.plot(points2, np.repeat(-0.01, class_sizes[1]), "r.", markersize = 10)\nplt.plot(points3, np.repeat(-0.01, class_sizes[2]), "r.", markersize = 10)\nplt.plot(points4, np.repeat(-0.01, class_sizes[3]), 
# ...

# %% [markdown]
# ## Algorithm Steps

# %%
def update_centroids(memberships, X):
    if memberships is None:
        # initialize centroids
        centroids = X[np.random.choice(range(N), K),:]
    else:
        # update centroids
        centroids = np.vstack([np.mean(X[memberships == k,], axis = 0) for k in range(K)])
    return(centroids)

def update_memberships(centroids, X):
    # calculate distances between centroids and data points
    D = spa.distance_matrix(centroids, X)
    # find the nearest centroid for each data point
    memberships = np.argmin(D, axis = 0)
    return(memberships)

# %% [markdown]
# ## Visualization

# %%
def plot_current_state(centroids, memberships, X):
    cluster_colors = np.array(["#e41a1c", "#377eb8", "#4daf4a", "#984ea3", "#ff7f00"])
    cluster_colors = np.array(["#1f78b4", "#33a02c", "#e31a1c", "#ff7f00", "#6a3d9a", "#b15928",
                               "#a6cee3", "#b2df8a", "#fb9a99", "#fdbf6f", "#cab2d6", "#ffff99"])
    if memberships is None:
        plt.plot(X[:,0], X[:,1], ".", markersize = 10, color = "black")
    else:
        for c in range(K):
            plt.plot(X[memberships == c, 0], X[memberships == c, 1], ".", markersize = 10, 
                     color = cluster_colors[c])
    for c in range(K):
        plt.plot(centroids[c, 0], centroids[c, 1], "s", markersize = 12, 
                 markerfacecolor = cluster_colors[c], markeredgecolor = "black")
    plt.xlabel("x1")
    plt.ylabel("x2")

# %% [markdown]
# ## Iterations

# %%
centroids = None
memberships = None
iteration = 1
while iteration!=2:
    print("Iteration#{}:".format(iteration))

    old_centroids = centroids
    centroids = update_centroids(memberships, X)
    if np.alltrue(centroids == old_centroids):
        break
    else:
        plt.figure(figsize = (12, 6))    
        plt.subplot(1, 2, 1)
        plot_current_state(centroids, memberships, X)

    old_memberships = memberships
    memberships = update_memberships(centroids, X)
    if np.alltrue(memberships == old_memberships):
        plt.show()
        break
    else:
        plt.subplot(1, 2, 2)
        plot_current_state(centroids, memberships, X)
        plt.show()

    iteration = iteration + 1
# Out:
# Iteration#1:

# %%
"""def score(i,c):
    part2 =  math.exp((-0.5)* np.matmul(np.matmul(X[memberships == (c + 1)]-centroids[c],np.transpose(X[memberships == (c + 1)]-centroids[c])), sample_covariances[c] ))
    part1 = class_priors[c] * (np.matmul(np.transpose(X[memberships == (c + 1)]-centroids[c]),(X[memberships == (c + 1)] - centroids[c])))
    return part1*part2
                 
                """

# %%
y = np.concatenate((np.repeat(1, class_sizes[0]), np.repeat(2, class_sizes[1]), np.repeat(3, class_sizes[2]), np.repeat(4, class_sizes[3]), np.repeat(5, class_sizes[4])))

sample_covariances= [(np.matmul(np.transpose(X[memberships == (c + 1)]-centroids[c]),(X[memberships == (c + 1)] - centroids[c])))/class_sizes[c] for c in range(K)]
class_priors = [np.mean(memberships == (c + 1)) for c in range(K)]
sample_means = centroids
def score(i,c):
    part1 = class_priors[c] * (np.matmul((X[memberships == (c + 1)] - centroids[c]),np.transpose(X[memberships == (c + 1)]-centroids[c])))
    part2 =  math.exp((-0.5)* np.matmul(np.matmul(X[memberships == (c + 1)]-centroids[c],np.transpose(X[memberships == (c + 1)]-centroids[c])), sample_covariances[c,:] ))
    
    return part1*part2
                 
memberships = None
iteration = 1
scores=[]
for i in range(100):
    for c in range(K):
        #scores.append(score(i,c))
        pass

    
    
    
    
    
    

old_centroids = centroids
centroids = update_centroids(memberships, X)
old_memberships = memberships
memberships = update_memberships(centroids, X)

# %%
for i in range(100):
    for c in range(K):
        scores.append(score(i,c))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1a1b3c19e2b4> in <module>
#       1 for i in range(100):
#       2     for c in range(K):
# ----> 3         scores.append(score(i,c))
#       4
#
# <ipython-input-12-2a5c8ef09f3c> in score(i, c)
#       1 def score(i,c):
# ----> 2     part2 =  math.exp((-0.5)* np.matmul(np.matmul(X[memberships == (c + 1)]-centroids[c],np.transpose(X[memberships == (c + 1)]-centroids[c])), sample_covariances[c] ))
#       3     part1 = class_priors[c] * (np.matmul(np.transpose(X[memberships == (c + 1)]-centroids[c]),(X[memberships == (c + 1)] - centroids[c])))
#       4     return part1*part2
#       5
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 60)
